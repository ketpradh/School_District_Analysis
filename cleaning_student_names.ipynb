# %%
import pandas as pd

# %%
student_data_df = pd.read_csv("Resources/clean_students_complete.csv", dtype = "unicode")
school_data_df = pd.read_csv("Resources/schools_complete.csv")

# %%
student_data_df.head()
# Out:
#   Unnamed: 0 Student ID     student_name gender grade        school_name  \
# 0          0          0     Paul Bradley      M   9th  Huang High School
# 1          1          1     Victor Smith      M  12th  Huang High School
# 2          2          2  Kevin Rodriguez      M  12th  Huang High School
# 3          3          3    Richard Scott      M  12th  Huang High School
# 4          4          4       Bonnie Ray      F   9th  Huang High School
#
#   reading_score math_score
# 0            66         79
# 1            94         61
# 2            90         60
# 3            67         58
# 4            97         84

# %%
student_data_list = student_data_df["student_name"].tolist()
student_data_list
# Out:
# ['Paul Bradley',
#  'Victor Smith',
#  'Kevin Rodriguez',
#  'Richard Scott',
#  'Bonnie Ray',
#  'Bryan Miranda',
#  'Sheena Carter',
#  'Nicole Baker',
#  'Michael Roth',
#  'Matthew Greene',
#  'Andrew Alexander',
#  'Daniel Cooper',
#  'Brittney Walker',
#  'William Long',
#  'Tammy Hebert',
#  'Jordan Carson',
#  'Donald Zamora',
#  'Kimberly Santiago',
#  'Kevin Stevens',
#  'Brandi Lyons',
#  'Lisa Davis',
#  'Kristen Lopez',
#  'Kimberly Stewart',
#  'Christopher Parker',
#  'Chelsea Griffith',
#  'Cesar Morris',
#  'Melanie Decker',
#  'Tracey Oconnor',
#  'Kelly James',
#  'Nicole Brown',
#  'Bobby Harris',
#  'Brian Fernandez',
#  'Candace Phelps',
#  'Amy Gonzalez',
#  'Steven Green',
#  'Benjamin Carlson',
#  'Kevin Bailey',
#  'Jesse Newton',
#  'Kimberly Mercado',
#  'Gregory Roberts',
#  'Matthew Mayer',
#  'Jennifer Parks',
#  'John Carlson',
#  'Megan Roberts',
#  'Debra Flores',
#  'Heidi Jackson',
#  'Denise Bradford',
#  'Ellen Brown',
#  'Amy Perkins',
#  'Natalie Mitchell',
#  'Tiffany Gutierrez',
#  'Jennifer Hess',
#  'Christine Fletcher',
#  'Jon Smith',
#  'Tracey Yates',
#  'Jerry Gordon',
#  'Michael Cox',
#  'Madeline Snyder',
#  'Allison King',
#  'Theresa Meyer',
#  'Jared Wood',
#  'Eric Maynard',
#  'Mark Owens',
#  'Ronnie Conley',
#  'Kimberly Davis',
#  'Amy Mitchell',
#  'Dylan Taylor',
#  'Elizabeth Henderson',
#  'James Lopez',
#  'Michael Morgan',
#  'Angela Francis',
#  'Breanna Taylor',
#  'Jason Johnson',
#  'Kyle Martin',
#  'Scott Gill',
#  'Lisa Long',
#  'Erin Liu',
#  'Marcus Richards',
#  'Jason Thompson',
#  'Elizabeth Mckinney',
#  'Jessica Bailey',
#  'Lisa Frye',
#  'Lindsey Baker',
#  'Lisa Ramirez',
#  'Joseph Butler',
#  'Tina Lynch',
#  'Leah Benitez',
#  'Elizabeth Parker',
#  'Melissa Hunter',
#  'Madison Everett',
#  'Ronald Garcia',
#  'Mark Cherry',
#  'Ryan Stokes',
#  'Isaiah Maldonado',
#  'Micheal Dennis',
#  'Kevin Martinez',
#  'Jessica Smith',
#  'Dawn Trujillo',
#  'Virginia Ramirez',
#  'Marc Hernandez',
#  'Jose Gonzalez',
#  'Jason Dennis',
#  'Gary Morris',
#  'William Mcdonald',
#  'Michael Savage',
#  'Alexis Todd',
#  'David Hansen',
#  'Steven Mendez',
#  'Ryan Lynch',
#  'Timothy Marks',
#  'Alexander Johns',
#  'Kenneth Chavez',
#  'Dennis Williams',
#  'Michael Roy',
#  'Richard Ryan',
#  'Matthew Reyes',
#  'Stephanie Ward',
#  'Christopher Tucker',
#  'Daniel Jones',
#  'Devin Craig',
#  'Erin Prince',
#  'Bernard Ortiz',
#  'Nicole Miller',
#  'Christopher Fritz',
#  'Bonnie Mckinney',
#  'Troy Nelson',
#  'Jennifer Lee',
#  'Ronald Ward',
#  'Nathaniel Hampton',
#  'Michael Travis',
#  'James Taylor',
#  'Thomas Strickland',
#  'Brittany Jackson',
#  'Marisa Lowe',
#  'Nicole Thomas',
#  'Matthew Rodriguez',
#  'Kent Fernandez',
#  'Michelle Martin',
#  'John Sparks',
#  'Ann Blake',
#  'Melissa Miller',
#  'Steven Houston',
#  'Kristen Anderson',
#  'Cory Jones',
#  'Jennifer Mora',
#  'Dennis Griffin',
#  'Darryl Brown',
#  'Martin Mosley',
#  'Joyce Diaz',
#  'Jeffrey Rose',
#  'Jamie Moreno',
#  'Catherine Williams',
#  'Lauren Byrd',
#  'Vanessa Frazier',
#  'Stephen Bryant',
#  'Lawrence Liu',
#  'Joseph Larsen',
#  'Susan Collier',
#  'Meagan Jensen',
#  'Julie Harper',
#  'Meghan Carroll',
#  'Wanda Horton',
#  'Mary Campbell',
#  'Jennifer Rodgers',
#  'Heather Cooper',
#  'Ryan Perez',
#  'Ryan Cox',
#  'Darren Zavala',
#  'Joseph Morales III',
#  'Aaron West',
#  'James Combs',
#  'Curtis Garner',
#  'Sarah Miller',
#  'Samantha Thomas',
#  'Robert Atkins',
#  'Alexis Crawford',
#  'Ryan Maddox',
#  'Jonathan Meyer',
#  'Donna Wagner',
#  'William Kennedy',
#  'Kimberly Martinez',
#  'Matthew Anderson',
#  'Kari Miller',
#  'Jenna Luna',
#  'Justin Contreras',
#  'Mary Fox',
#  'Joseph Perkins',
#  'Kelly Phillips',
#  'Justin Thornton',
#  'Joshua Barber',
#  'Travis Jackson',
#  'Jordan Beasley',
#  'Kevin Allen',
#  'Victoria Harris',
#  'Victoria Joseph',
#  'Brandy Marshall',
#  'Ryan Jimenez',
#  'Michael Chan',
#  'Christopher Phillips',
#  'Kevin Murphy',
#  'Vanessa Harper',
#  'James Ferguson',
#  'Carol Schroeder',
#  'Jerry Phillips',
#  'Kristin Wade',
#  'Jessica Warner',
#  'Dorothy Burke',
#  'Bethany Walter',
#  'Melissa Avery',
#  'Daniel Sutton',
#  'Ryan Johnson',
#  'Timothy Quinn',
#  'Zachary Allen',
#  'Lauren Schmitt',
#  'Stephanie Armstrong',
#  'Ruben Rivera',
#  'Patricia Petty',
#  'Joseph Jacobs',
#  'Bianca Wilson',
#  'Donald Perez',
#  'Curtis Gomez',
#  'Courtney Brown',
#  'Nicole Randall',
#  'Steven Lambert',
#  'Anthony Alvarez',
#  'Shawn Farrell',
#  'Jesus Schmidt',
#  'Laura Wright',
#  'Steven Smith',
#  'Norman Thompson',
#  'Anthony Wright',
#  'Kayla Watts',
#  'Aimee Johnson',
#  'Heidi Scott',
#  'Anthony Williams',
#  'Sarah Hill',
#  'Kim Wang',
#  'Beth Manning',
#  'Ryan Hanson',
#  'James Wood',
#  'Corey Greene',
#  'John Carter',
#  'Beth Garza',
#  'Karen Jones',
#  'Stephanie Poole',
#  'Lisa Brown',
#  'Paul Scott',
#  'Evelyn Buck',
#  'Terry Harrell',
#  'Leah Skinner',
#  'Anthony Mercado',
#  'Walter Kelly',
#  'Lori Evans',
#  'Ashley Jones',
#  'Amber Soto',
#  'Patrick Phillips',
#  'Linda Curry',
#  'Alexander Obrien',
#  'Vincent Garza',
#  'Terry Marsh',
#  'Angela Perkins',
#  'Peter Hampton',
#  'David Cross',
#  'Clinton Ortega',
#  'Jamie Escobar',
#  'Sandra Mason',
#  'Craig Cole',
#  'Lisa Warren',
#  'Maria Howard',
#  'Michael Porter',
#  'John Turner',
#  'Timothy Wang',
#  'Amanda Taylor',
#  'Karen Mckenzie',
#  'Brandon Miles',
#  'Christina Whitaker',
#  'Nicole Peterson',
#  'Ashley Moore',
#  'Todd Carrillo',
#  'Robert Williams',
#  'Ashley Jones',
#  'Vanessa Parker',
#  'Robert Carlson',
#  'Jared Lewis',
#  'Christopher Hernandez',
#  'Kimberly Harris',
#  'Katrina Hill',
#  'Heather Lee',
#  'Donald Harmon',
#  'Elizabeth Sanders',
#  'Richard Ramsey',
#  'Carmen Johnson',
#  'Elaine Osborne',
#  'Kent Burns',
#  'Meagan Smith',
#  'Craig Hahn',
#  'Jeremy Wu',
#  'Aaron Rodriguez',
#  'Matthew Taylor',
#  'Diana Evans',
#  'Michele Pearson',
#  'Erik Wagner',
#  'Maria Welch',
#  'Debra Martin',
#  'Devon Conner',
#  'Christine Patel',
#  'David Lopez',
#  'Nathan Baird',
#  'Samuel Castillo',
#  'Rebecca Payne',
#  'Carl Johnson',
#  'William Adams',
#  'Paula Harrison',
#  'Wayne Atkinson',
#  'Lindsay Frank',
#  'Jose Garcia',
#  'Andrew Gaines',
#  'Rachael Liu',
#  'Donald Lewis',
#  'Shane Edwards',
#  'Todd Levy',
#  'Joanna Moore',
#  'Michael Lewis',
#  'James Robinson',
#  'Jeffrey Arellano',
#  'Heather Allen',
#  'Lori Villarreal',
#  'Robert Harper',
#  'Karen Villegas',
#  'Tracey Crane',
#  'Elizabeth Allen',
#  'Jorge Lynn',
#  'Harold Gordon',
#  'Nicholas Mcclain',
#  'Tanya Harris',
#  'Amy Smith',
#  'Kathy Morse',
#  'Andrea Wood',
#  'Maureen Massey',
#  'Daniel Smith',
#  'Alexandra Smith',
#  'Caitlin Hall',
#  'Jose Carlson',
#  'Deborah Macias',
#  'Dwayne Rice',
#  'Matthew Harris',
#  'Eric Bowman',
#  'Samuel Ali',
#  'David Miller',
#  'James Moreno',
#  'Brooke Austin',
#  'Alisha Martin',
#  'Neil Rodriguez',
#  'Gary Williams',
#  'Michael Pittman',
#  'Stephanie Palmer',
#  'Christine Perry',
#  'Suzanne David',
#  'Amber Smith',
#  'Ryan Jones',
#  'Emily Ford',
#  'Kelsey Shea',
#  'Katherine Wallace',
#  'Erica Conway',
#  'Tyler Parker',
#  'Michael Parks',
#  'Elizabeth Hunt',
#  'Grant Jackson',
#  'Daniel Matthews',
#  'Diana Silva',
#  'Frank Garza',
#  'Terri Fischer',
#  'Robert Goodwin',
#  'Bobby Ruiz',
#  'Stephanie Taylor',
#  'Erin Hill',
#  'Erin Cohen',
#  'Jeffrey Morris',
#  'Elizabeth Simpson',
#  'Jennifer Davis',
#  'Rachel Burton',
#  'Joseph Wilkins',
#  'Lawrence Montgomery',
#  'Patricia Howard',
#  'Jessica Hanson',
#  'Donna Dean',
#  'Edwin Reid',
#  'Jodi Brown',
#  'Elizabeth Richard',
#  'Aaron Martinez',
#  'Stephen Fischer',
#  'Diana Reeves',
#  'Jeffrey Eaton',
#  'Evelyn Miller',
#  'Christopher Kidd',
#  'Sarah Adams',
#  'Melinda Nelson',
#  'Kevin Brooks',
#  'John Bowen',
#  'Tracie Abbott',
#  'Allen Foster',
#  'Kathryn Elliott',
#  'Christopher Walker',
#  'Cynthia Martin',
#  'Amanda Bennett',
#  'Dennis Padilla',
#  'Antonio Miller',
#  'Melissa Trevino',
#  'Andrew King',
#  'John Martinez',
#  'Lauren King',
#  'Stephanie Mercado',
#  'William Smith',
#  'Jonathan Marshall',
#  'Luke Lowery',
#  'Emily Reynolds',
#  'Kevin Mclean',
#  'Elizabeth Taylor',
#  'Pamela Rivas',
#  'Tammy Martin',
#  'Holly Watkins',
#  'Patrick Chen',
#  'Michelle Griffin',
#  'Theresa Andrews',
#  'Alan Henry',
#  'Larry Hines',
#  'Travis Frazier',
#  'Julie Jones',
#  'Natalie Reynolds',
#  'Jessica Cohen',
#  'Jason Robinson',
#  'Heather Palmer',
#  'Emily Cardenas',
#  'Scott Glover',
#  'Jacqueline White',
#  'Elizabeth Espinoza',
#  'Toni Porter',
#  'Jennifer Mejia',
#  'Brenda Peterson',
#  'Paul Hamilton',
#  'Patricia Nguyen',
#  'James Ho',
#  'Elizabeth Cohen',
#  'Stephanie Lane',
#  'Dawn Rhodes',
#  'Theresa Robinson',
#  'Breanna Mosley',
#  'Carmen Wilson',
#  'Ian Brown',
#  'Kathleen Matthews',
#  'Bryan Diaz',
#  'Gina Sweeney',
#  'Alan Garcia',
#  'Erik Wheeler',
#  'Stephanie Robles',
#  'Samantha Hanson',
#  'Christopher Williams',
#  'Stephanie Hart',
#  'Lisa Becker',
#  'Bianca Johnson',
#  'Amy Steele',
#  'Gina Contreras',
#  'Jaime Alexander',
#  'Kevin Coleman',
#  'Caitlin Williams',
#  'Joseph Lloyd',
#  'Carrie Hernandez',
#  'Travis Young',
#  'Francis Wright',
#  'Joel Harper',
#  'Eduardo Park',
#  'Melissa Yoder',
#  'Donna Campbell',
#  'Connie Delacruz',
#  'Luis Parker',
#  'Pamela Watts',
#  'Lindsey Mitchell',
#  'Brenda Price',
#  'Joseph Howard',
#  'Amy Evans',
#  'Paula Fernandez',
#  'Amber Cunningham',
#  'Preston Wheeler',
#  'James Lopez',
#  'Chad Drake',
#  'Samuel Blackburn',
#  'Shawn Nielsen',
#  'Eric Perez',
#  'Kevin Montgomery',
#  'Terry Thomas',
#  'Kim Meyer',
#  'Michael Townsend',
#  'Ronnie Rodriguez',
#  'Savannah Smith',
#  'Shane Nguyen',
#  'Michael Brown',
#  'Robert Young',
#  'Daniel Griffin',
#  'James Johnson',
#  'Mary Cox',
#  'Tina Aguirre',
#  'Jillian Mcdonald',
#  'Matthew Branch',
#  'Christopher Jordan',
#  'Victor Mcguire',
#  'Erin Arnold',
#  'Nicholas Wu',
#  'Kristen Wilson',
#  'Morgan Moore',
#  'Stephen Smith',
#  'Jeremy Romero',
#  'Julie Bush',
#  'Brittany Taylor',
#  'James Kim',
#  'Ashley Roberts',
#  'Brandon Johnson',
#  'David Davenport',
#  'Mark Washington',
#  'Alicia Marshall',
#  'Barbara Santana',
#  'Samantha Parker',
#  'Joseph Walters',
#  'Michael Zamora',
#  'Kyle Cobb',
#  'Jill Clark',
#  'Sarah Warren',
#  'Jennifer Robinson',
#  'Patricia Johnson',
#  'Henry Evans',
#  'Alexander Ramsey',
#  'Brandon Stephens',
#  'Jeff Holland',
#  'Samuel Schultz',
#  'Brett Johnson',
#  'Daniel Sherman',
#  'Justin Mccall',
#  'Jonathan Evans',
#  'Jacqueline Kennedy',
#  'Martin Stephenson',
#  'Lindsey Lane',
#  'Jessica Hart',
#  'Edward Lucas',
#  'Lisa Osborne',
#  'Hannah Black',
#  'Alexander Paul',
#  'Brenda Wong',
#  'Thomas Delgado',
#  'Jeremy Sutton',
#  'Paula Donaldson',
#  'Valerie Thompson',
#  'John Schaefer',
#  'Jesus Manning',
#  'Tyrone Lawson',
#  'Carl May',
#  'Brittany Russell',
#  'Philip Edwards',
#  'Robert Aguilar',
#  'Aaron Russo',
#  'Tracy Andrade',
#  'Amy Sullivan',
#  'Howard Beck',
#  'Xavier Bell II',
#  'Dawn Schultz',
#  'Caleb Lucas',
#  'Barbara Gonzalez',
#  'Charles Yang',
#  'David Gallagher',
#  'Bethany Vargas',
#  'Jennifer Schultz',
#  'Paula Marshall',
#  'Jordan Elliott',
#  'Samantha Mcmillan',
#  'Judith Johnson',
#  'Grace Palmer',
#  'Brandon Ramirez',
#  'Carol Smith',
#  'Matthew Odom',
#  'Erika Gray',
#  'Donna Kramer',
#  'Jonathan Snyder',
#  'Frank Howe',
#  'Amy Beck',
#  'Lori Holmes',
#  'Rebekah Hampton',
#  'Perry Bishop',
#  'Andrew Hanson',
#  'Jody Hughes',
#  'Anna Garcia',
#  'Colleen Walker',
#  'Danny Bridges',
#  'Kristina Ford',
#  'Sabrina Davidson',
#  'Alexander Freeman',
#  'Jack Davis',
#  'Victor Rivera',
#  'Elizabeth Pena',
#  'Neil Castro',
#  'Michael Briggs',
#  'Anna Andersen',
#  'Elizabeth Oconnor',
#  'Zachary Brooks',
#  'Scott Jackson',
#  'Mary Fuentes',
#  'Denise Reyes',
#  'Janice Collier',
#  'Tina Barber',
#  'Keith Rojas',
#  'Michelle Decker',
#  'James Smith',
#  'Alexandra Thompson',
#  'Jacqueline Campbell',
#  'Austin Clark',
#  'Brooke Thomas',
#  'Molly Smith',
#  'Pamela Beck',
#  'Timothy Morris',
#  'Lauren White',
#  'Jessica Beltran',
#  'Alexandra Jones',
#  'Evelyn Rice',
#  'Stephen Ellis',
#  'Caroline Smith',
#  'Fred Case',
#  'Crystal Anderson',
#  'Jordan Gross',
#  'Marie Harris',
#  'Charles Hayes',
#  'Beverly Sheppard',
#  'Denise Solis',
#  'Alexander Myers',
#  'Sally Robertson',
#  'Steven Morris',
#  'Nina Flores',
#  'Miguel Patterson',
#  'John Simpson',
#  'Charles Cruz',
#  'Monica Davis',
#  'James Fields',
#  'Kevin Frederick',
#  'Jeremy Soto',
#  'Ronald Harris',
#  'Carol Stewart',
#  'Albert Durham',
#  'James Sanchez',
#  'John Adams',
#  'Cody Williams',
#  'Ernest Love',
#  'Tommy Smith',
#  'Jared Anderson',
#  'Jennifer Yang',
#  'Joe Mercado',
#  'Roberto Wright',
#  'Michael Smith',
#  'William Park',
#  'Benjamin Williams',
#  'Dean Perez',
#  'Dale Miller',
#  'Marissa Russell',
#  'Mary Gonzalez',
#  'April Jackson',
#  'William Hayes',
#  'Meghan Holloway',
#  'Amy Coleman',
#  'James Green',
#  'Michael Tran',
#  'Joseph Cortez',
#  'Anita Moss',
#  'Benjamin Stokes',
#  'Michael Li',
#  'Alexander Rosales',
#  'Katie Dawson',
#  'Shelly Erickson',
#  'Kathryn Turner',
#  'Jacob Lee',
#  'Ryan Smith',
#  'Joshua Fernandez',
#  'Mia Roach',
#  'William Rodriguez',
#  'Wanda Cruz',
#  'Pamela Hall',
#  'David Smith',
#  'Jason Brown',
#  'Chelsea Alexander',
#  'Kimberly Tate',
#  'Daniel Williams',
#  'Terri Jacobson',
#  'Paul Harris',
#  'Jessica Thompson',
#  'Nancy Hawkins',
#  'Deborah Phillips',
#  'Mark Mendoza',
#  'Stephen Williamson',
#  'Jennifer Strong',
#  'Matthew Moore',
#  'Raymond Parker',
#  'Lee Evans',
#  'Curtis Rodriguez',
#  'Sara Morris',
#  'Dawn Palmer',
#  'Brianna Benson',
#  'Luis Watts',
#  'Cindy Brown',
#  'Summer Sandoval',
#  'Ashley Smith',
#  'Randy Wallace',
#  'Angela Simmons',
#  'Sandra Haley',
#  'George Morgan',
#  'Melissa Ali',
#  'Matthew Oliver',
#  'Michael Kirk',
#  'Terry Khan',
#  'Kristie Elliott',
#  'Joel Campbell',
#  'Anthony Henderson',
#  'Brent Christensen',
#  'Heidi Hayes',
#  'Ryan Mcbride',
#  'Kyle Murillo',
#  'Angela Powell',
#  'Jeanette Simmons',
#  'Adam Vance',
#  'Kristen Murray',
#  'Jessica Burnett',
#  'Alex Walker',
#  'Robert Phillips',
#  'Elizabeth Martinez',
#  'Kristina Young',
#  'Sarah Morgan',
#  'Cheryl Harding',
#  'Keith Hunter',
#  'Todd Williams',
#  'James White',
#  'Kyle Johnson',
#  'Andrea Suarez',
#  'Michael Sanchez',
#  'Jaime Torres',
#  'Donald Gill',
#  'Austin Lee',
#  'Adrian Bowman',
#  'Julie Perez',
#  'Debra Maxwell',
#  'Bradley Phillips',
#  'Sonya Simmons',
#  'Eric Miller',
#  'Charles Berger',
#  'Mary Monroe',
#  'Destiny Burns',
#  'Patrick Khan',
#  'Nathaniel Henson',
#  'Larry Miller',
#  'Timothy French',
#  'Xavier Mitchell',
#  'Jason Crosby',
#  'Joshua Johnson',
#  'Alyssa Clark',
#  'Jonathan Cooper',
#  'Mark Hunt',
#  'Norman Moore',
#  'Brian Atkins',
#  'Zachary Jones',
#  'Danielle Wong',
#  'Patricia Lane',
#  'Joshua Rose',
#  'Hannah Montes',
#  'Catherine Williams',
#  'Michael Jenkins',
#  'James Scott',
#  'Evan Ballard',
#  'Andrea Miller',
#  'Jasmine Lynch',
#  'Jennifer Fox',
#  'Jared Castro',
#  'Eugene Cox',
#  'Wendy Wilson',
#  'Debbie Smith',
#  'Michael Fletcher',
#  'Jay Waters',
#  'Melissa Martinez',
#  'Cory Howard',
#  'Mitchell Hanson',
#  'Corey Boyer',
#  'Elizabeth Gonzalez',
#  'Robert Hutchinson',
#  'David Hernandez',
#  'Tammy Jordan',
#  'Denise Johnson',
#  'Brandi Copeland',
#  'Evan Marshall',
#  'Gregory Long',
#  'Kristen Underwood',
#  'Walter French',
#  'Edwin Thompson',
#  'Edward Rivera',
#  'Brandon Wilson',
#  'Alejandra Todd',
#  'Dana Hoffman',
#  'David Howard',
#  'Ashley Caldwell',
#  'Cindy Horn',
#  'Kevin Armstrong',
#  'Stacey Porter',
#  'Patrick Hunt',
#  'David White',
#  'Tammy Black',
#  'Joanna Williams',
#  'Becky Moran',
#  'Brenda Smith',
#  'Gabrielle Webb',
#  'Jared Campbell',
#  'Ryan Jenkins',
#  'Thomas Shepard',
#  'Jeremiah Boyd',
#  'Matthew White',
#  'Christina Anderson',
#  'Edward Olson',
#  'Emily Bryant',
#  'Amy Guzman',
#  'Kathleen Owens',
#  'John Davila',
#  'Nicole King',
#  'Jason Villarreal',
#  'Matthew Washington',
#  'Peter Simpson',
#  'Cristian Espinoza',
#  'Steven Fry',
#  'David Miller',
#  'Tamara Hernandez',
#  'Jordan Lewis',
#  'Carol Anderson',
#  'Michael Moreno',
#  'Nicholas Logan',
#  'Paul Anderson',
#  'Jason Young',
#  'Wesley Martin',
#  'Karen Wall',
#  'Tara Parker',
#  'Michael Reyes',
#  'Amy Henderson',
#  'Jessica Reed',
#  'Joseph Miranda',
#  'Mackenzie Jones',
#  'Jon Espinoza',
#  'Kelly Medina',
#  'Jason Rubio',
#  'Jennifer Munoz',
#  'Christopher Warner',
#  'Vincent Thomas',
#  'Andrew Young',
#  'David Jenkins',
#  'Daniel Stephens',
#  'Elizabeth Lewis',
#  'Aaron Moore',
#  'Lisa Hogan',
#  'Shawn Williams',
#  'Michele Dickerson',
#  'Alicia Martinez',
#  'Timothy Anderson',
#  'Sierra Jackson',
#  'Sharon Taylor',
#  'Jeffrey Smith',
#  'Mark Taylor',
#  'Christina Ross',
#  'Judy Hall',
#  'Jennifer Fox',
#  'Kenneth Moran',
#  'Gerald Ferguson',
#  'Albert Carter',
#  'Michael Reilly',
#  'Kathleen Schwartz',
#  'Stacey Harris',
#  'Paula Lee',
#  'Adrian Black',
#  'Rita Moreno',
#  'Jason Perry',
#  'Scott Ortiz',
#  'Randy Mueller',
#  'Samantha Anderson',
#  'Phillip Brown',
#  'Christina Kerr',
#  'Derrick Hill',
#  'Nathan Bond',
#  'Marie Wilson',
#  'Caitlin Jones',
#  'Barbara Campbell',
#  'Katie Gonzales',
#  'Elijah Hall',
#  'James Sanders',
#  'Nicholas Martinez',
#  'Maria Mack',
#  'Mary Mason',
#  'Tiffany Campbell',
#  'Raymond Stone',
#  'Dominique Henderson',
#  'Martin Williams',
#  'Hannah Parker',
#  'Susan Webb',
#  'Rachel Johnson',
#  'Darren Davis',
#  'Tim Carr',
#  'Jesus Ryan',
#  'John Hays',
#  'Scott Stewart',
#  'Alexandra Roberts',
#  'Amanda Norman',
#  'James Moody',
#  'Brenda Jones',
#  'Kathy Smith',
#  'Raymond Clark',
#  'Ashley Martin',
#  'Tamara Flowers',
#  'Cesar Hanson',
#  'Ross Strickland',
#  'Randy Moore',
#  'Henry Andersen',
#  'Paul Martin',
#  'Sarah Stanley',
#  'Jordan Lewis',
#  'Ashley Richardson',
#  'Michael Brown',
#  'Jason Davis',
#  'Wendy Mcclain',
#  'Troy Williams',
#  'Carrie Alexander',
#  'Kyle Ware',
#  'Michael Robinson',
#  'Roger Wilson',
#  'Teresa Fuller',
#  'Craig Silva',
#  'Duane Thomas',
#  'Jon Crosby',
#  'Jon Steele',
#  'Daniel Shaw',
#  'Gwendolyn Williams',
#  'Angela Hess',
#  'Cameron Arnold',
#  'Janice Garcia',
#  'Anne Bullock',
#  'Katie Moody',
#  'Kayla Rivas',
#  'Danny Pearson',
#  'Billy Robles',
#  'Michelle Delgado',
#  'Cindy Harrison',
#  'John Dickerson',
#  'Tina Armstrong',
#  'Alex Franklin',
#  'Ryan King',
#  'Christine Guzman',
#  'Helen Malone',
#  'Benjamin Carpenter',
#  'Jessica Dunn',
#  'Jessica Kaiser',
#  'Brandon Black',
#  'David Hernandez',
#  'Brenda Turner',
#  'Katherine Black',
#  'Larry Santos',
#  'Zachary Dominguez',
#  'Tanya Fernandez',
#  'Joseph Nichols',
#  'Rebecca Martinez',
#  'Traci Ramirez',
#  'Ryan Bauer',
#  'Joshua Williams',
#  'Devon Foley',
#  'Heidi Walter',
#  'Mario Nguyen',
#  'Jordan Hernandez',
#  'William Miller',
#  'Nicholas Chung',
#  'Christine Cooley',
#  'Carrie Nelson',
#  'Crystal Fowler',
#  'Lori Taylor',
#  'Michael Stevenson',
#  'Matthew Holmes',
#  'David Walls',
#  'Megan Martin',
#  'Karen Peterson',
#  'Kristen Wallace',
#  'Mark Peterson',
#  'Jason Jones',
#  'Keith Barber',
#  'Patrick Green',
#  'Antonio Lopez',
#  'Travis Peterson',
#  'Gabriel Hunter',
#  'Amanda Ross',
#  'Samuel Thompson',
#  'Robert Bowman',
#  'Cynthia Cox',
#  'Brittany Miller',
#  'Eric Torres',
#  'Sandra Calhoun',
#  'Jacob Bailey',
#  'Jessica Harris',
#  'Molly Carr',
#  'Keith Davis',
#  'Adriana Wade',
#  ...]

# %%
name = "Mrs. Linda Santiago"
name_list = name.split()
len(name_list)
# Out:
# 3

# %%
# Create a new list and use it for the for loop to iterate through the list.
students_to_fix = []

for student in student_data_list:
    if (len(student.split()) > 2 ):
        students_to_fix.append(student)

len(students_to_fix)
# Out:
# 151

# %%
# Add the prefixes less than or equal to 4 to a new list.
prefixes = []
for name in students_to_fix:
    if len(name.split()[0]) <= 4:
        prefixes.append(name.split()[0])

print(prefixes)
# Out:
# ['Juan', 'Mark', 'Sean', 'Cody', 'Ryan', 'Eric', 'Jon', 'Noah', 'Eric', 'Todd', 'Mark', 'Eric', 'Adam', 'Cory', 'Jon', 'Greg', 'Ryan', 'Erik', 'Omar', 'Seth', 'Tony', 'Mark']

# %%
# Add the prefixes less than or equal to 4 to a new list.
suffixes = []
for name in students_to_fix:
    if len(name.split()[-1]) <= 3:
        suffixes.append(name.split()[-1])

print(suffixes)
# Out:
# ['III', 'II', 'Jr.', 'IV', 'IV', 'Jr.', 'II', 'Jr.', 'III', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'II', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'III', 'Jr.', 'II', 'II', 'II', 'Jr.', 'II', 'IV', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'V', 'II', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'III', 'Jr.', 'Jr.', 'II', 'III', 'Jr.', 'II', 'Jr.', 'Jr.', 'III', 'Jr.', 'Jr.', 'Jr.', 'II', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'II', 'Jr.', 'III', 'Jr.', 'V', 'Jr.', 'Jr.', 'IV', 'Jr.', 'Jr.', 'II', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'II', 'III', 'Jr.', 'IV', 'Jr.', 'Jr.', 'III', 'III', 'Jr.', 'III', 'Jr.', 'II', 'Jr.', 'II', 'Jr.', 'II', 'Jr.', 'II', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'II', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'II', 'Jr.', 'Jr.', 'Jr.', 'IV', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'III', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'Jr.', 'II', 'Jr.', 'III', 'II', 'III', 'II', 'II', 'Jr.', 'IV', 'Jr.', 'III', 'II', 'Jr.', 'Jr.', 'Jr.', 'Jr.']

# %%
# Get the unique items in the "prefixes" list.
set(prefixes)
# Out:
# {'Adam',
#  'Cody',
#  'Cory',
#  'Eric',
#  'Erik',
#  'Greg',
#  'Jon',
#  'Juan',
#  'Mark',
#  'Noah',
#  'Omar',
#  'Ryan',
#  'Sean',
#  'Seth',
#  'Todd',
#  'Tony'}

# %%
# Get the unique items in the "suffixes" list.
set(suffixes)
# Out:
# {'II', 'III', 'IV', 'Jr.', 'V'}

# %%
# Replace "Dr." with an empty string.
name = "Dr. Linda Santiago"
name.replace("Dr. ", "")
# Out:
# 'Linda Santiago'

# %%
# Add each prefix and suffix to remove to a list.
prefixes_suffixes = ["Dr. ", "Mr. ","Ms. ", "Mrs. ", "Miss ", " MD", " DDS", " DVM", " PhD"]
# Iterate through the "prefixes_suffixes" list and replace them with an empty space, "" when it appears in the student's name.
for word in prefixes_suffixes:
    student_data_df["student_name"] = student_data_df["student_name"].str.replace(word,"")

student_data_df.head(10)
# Out:
#   Unnamed: 0 Student ID     student_name gender grade        school_name  \
# 0          0          0     Paul Bradley      M   9th  Huang High School
# 1          1          1     Victor Smith      M  12th  Huang High School
# 2          2          2  Kevin Rodriguez      M  12th  Huang High School
# 3          3          3    Richard Scott      M  12th  Huang High School
# 4          4          4       Bonnie Ray      F   9th  Huang High School
# 5          5          5    Bryan Miranda      M   9th  Huang High School
# 6          6          6    Sheena Carter      F  11th  Huang High School
# 7          7          7     Nicole Baker      F  12th  Huang High School
# 8          8          8     Michael Roth      M  10th  Huang High School
# 9          9          9   Matthew Greene      M  10th  Huang High School
#
#   reading_score math_score
# 0            66         79
# 1            94         61
# 2            90         60
# 3            67         58
# 4            97         84
# 5            94         94
# 6            82         80
# 7            96         69
# 8            95         87
# 9            96         84

# %%
# Put the cleaned students' names in another list.
i = 0
student_names = student_data_df["student_name"].tolist()
for student in student_names:
    if((len(student.split()))> 2):
        #print(student, len(student.split()))
        i = i + 1

i
# Out:
# 151

# %%
# Create a new list and use it for the for loop to iterate through the list.
students_fixed = []

# Use an if statement to check the length of the name.

# If the name is greater than or equal to 3, add the name to the list.

for name in student_names:
    if len(name.split()) >= 3:
        students_fixed.append(name)

# Get the length of the students' names that are greater than or equal to 3.
len(students_fixed)
# Out:
# 151

# %%
# Add each prefix and suffix to remove to a list.
prefixes_suffixes = ["Dr. ", "Mr. ","Ms. ", "Mrs. ", "Miss ", " MD", " DDS", " DVM", " PhD"]

student_data_df.head(10)

for word in prefixes_suffixes:
    student_data_df["student name"] = student_data_df["student_name"].str.replace(word, "")

student_data_df.head(10)
# Out:
#   Unnamed: 0 Student ID     student_name gender grade        school_name  \
# 0          0          0     Paul Bradley      M   9th  Huang High School
# 1          1          1     Victor Smith      M  12th  Huang High School
# 2          2          2  Kevin Rodriguez      M  12th  Huang High School
# 3          3          3    Richard Scott      M  12th  Huang High School
# 4          4          4       Bonnie Ray      F   9th  Huang High School
# 5          5          5    Bryan Miranda      M   9th  Huang High School
# 6          6          6    Sheena Carter      F  11th  Huang High School
# 7          7          7     Nicole Baker      F  12th  Huang High School
# 8          8          8     Michael Roth      M  10th  Huang High School
# 9          9          9   Matthew Greene      M  10th  Huang High School
#
#   reading_score math_score     student name
# 0            66         79     Paul Bradley
# 1            94         61     Victor Smith
# 2            90         60  Kevin Rodriguez
# 3            67         58    Richard Scott
# 4            97         84       Bonnie Ray
# 5            94         94    Bryan Miranda
# 6            82         80    Sheena Carter
# 7            96         69     Nicole Baker
# 8            95         87     Michael Roth
# 9            96         84   Matthew Greene

# %%
# Combine the data into a single dataset.
school_data_complete_df = pd.merge(student_data_df, school_data_df, on=["school_name", "school_name"])
school_data_complete_df.head()
# Out:
#   Unnamed: 0 Student ID     student_name gender grade        school_name  \
# 0          0          0     Paul Bradley      M   9th  Huang High School
# 1          1          1     Victor Smith      M  12th  Huang High School
# 2          2          2  Kevin Rodriguez      M  12th  Huang High School
# 3          3          3    Richard Scott      M  12th  Huang High School
# 4          4          4       Bonnie Ray      F   9th  Huang High School
#
#   reading_score math_score     student name  School ID      type  size  \
# 0            66         79     Paul Bradley          0  District  2917
# 1            94         61     Victor Smith          0  District  2917
# 2            90         60  Kevin Rodriguez          0  District  2917
# 3            67         58    Richard Scott          0  District  2917
# 4            97         84       Bonnie Ray          0  District  2917
#
#     budget
# 0  1910635
# 1  1910635
# 2  1910635
# 3  1910635
# 4  1910635

# %%
# Get the total number of students.
student_count = school_data_complete_df["student_name"].count()
student_count
# Out:
# 39170

# %%
#Get the number of schools.
school_count = school_data_df["School ID"].count()
school_count
#Get the number of schools.- another way
school_count_list = school_data_complete_df["School ID"].unique()
len(school_count_list)
# Out:
# 15

# %%
# Calculate the total budget.
total_budget = school_data_df["budget"].sum()
total_budget
# Calculate the total budget.- another way?
total_budget_2 = school_data_complete_df["budget"].unique().sum()
total_budget_2
# Out:
# 24649428

# %%
# Calculate the average reading score.
average_reading_score = school_data_complete_df["reading_score"].mean()
average_reading_score
# Out:
# inf

# %%
# Calculate the average Math score.
average_math_score = school_data_complete_df["math_score"].mean()
average_math_score
# Out:
# inf

# %%
passing_math = school_data_complete_df[(school_data_complete_df["math_score"] >= 70)]
passing_reading = school_data_complete_df[school_data_complete_df["reading_score"] >= 70]
print(passing_math["student_name"].count())
print(passing_reading["student_name"].count())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-309-fcde7253ee4c> in <module>
# ----> 1 passing_math = school_data_complete_df[(school_data_complete_df["math_score"] >= 70)]
#       2 passing_reading = school_data_complete_df[school_data_complete_df["reading_score"] >= 70]
#       3 print(passing_math["student_name"].count())
#       4 print(passing_reading["student_name"].count())
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     368         rvalues = extract_array(other, extract_numpy=True)
#     369
# --> 370         res_values = comparison_op(lvalues, rvalues, op)
#     371
#     372         return self._construct_result(res_values, name=res_name)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     242
#     243     elif is_object_dtype(lvalues.dtype):
# --> 244         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     245
#     246     else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\ops\array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      54         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      55     else:
# ---> 56         result = libops.scalar_compare(x.ravel(), y, op)
#      57     return result.reshape(x.shape)
#      58
#
# pandas\_libs\ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %%
passing_reading_percentage = passing_reading["student_name"].count()/float(student_count) * 100
passing_math_percentage =  passing_math["student_name"].count()/float(student_count) * 100

print(f'Percentage of students passing Math =',passing_math_percentage )
print(f'Percentage of students passing Reading =', passing_reading_percentage)

# %%
passing_both = school_data_complete_df[(school_data_complete_df["reading_score"] >= 70) &
                                       (school_data_complete_df["math_score"] >= 70) ]
passing_both
print(passing_both["student_name"].count())
overall_passing_percentage =passing_both["student_name"].count()/float(student_count) * 100
print(f'Percentage of students passing Reading and Math =',overall_passing_percentage)

# %%
# Create a new DataFrame to store output for the district
district_summary_df = district_summary_df = pd.DataFrame(
          [{"Total Schools": school_count,
          "Total Students": student_count,
          "Total Budget": total_budget,
          "Average Math Score": average_math_score,
          "Average Reading Score": average_reading_score,
          "% Passing Math": passing_math_percentage,
         "% Passing Reading": passing_reading_percentage,
        "% Overall Passing": overall_passing_percentage}])
district_summary_df

# %%
# Format the "Total Students" to have the comma for a thousands separator.
district_summary_df["Total Students"] = district_summary_df["Total Students"].map("{:,}".format)

district_summary_df["Total Students"]

# %%
# Format "Total Budget" to have the comma for a thousands separator, a decimal separator, and a "$".

district_summary_df["Total Budget"] = district_summary_df["Total Budget"].map("${:,.2f}".format)

district_summary_df["Total Budget"]

# %%
# Format the columns.
district_summary_df["Average Math Score"] = district_summary_df["Average Math Score"].map("{:.1f}".format)

district_summary_df["Average Reading Score"] = district_summary_df["Average Reading Score"].map("{:.1f}".format)

district_summary_df["% Passing Math"] = district_summary_df["% Passing Math"].map("{:.0f}".format)

district_summary_df["% Passing Reading"] = district_summary_df["% Passing Reading"].map("{:.0f}".format)

district_summary_df["% Overall Passing"] = district_summary_df["% Overall Passing"].map("{:.0f}".format)

# %%
district_summary_df

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ["Total Schools", "Total Students", "Total Budget","Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing"]

# Assign district summary df the new column order.
district_summary_df = district_summary_df[new_column_order]
district_summary_df

# %%
    # Determine the school type.
per_school_types = school_data_df.set_index(["school_name"])["type"]
per_school_types

# %%
# Add the per_school_types into a DataFrame for testing.
df = pd.DataFrame(per_school_types)
df

# %%
# Calculate the total student count.
per_school_counts = school_data_df.set_index(["school_name"])["size"]
per_school_counts

# Calculate the total student count.
per_school_counts = school_data_complete_df["school_name"].value_counts()
per_school_counts

# %%
# Calculate the total school budget.
per_school_budget = school_data_df.set_index(["school_name"])["budget"]
per_school_budget

# %%
# Calculate the per capita spending.
per_school_capita = per_school_budget / per_school_counts
per_school_capita

# %%
# Calculate the math scores.
student_school_math = student_data_df.set_index(["school_name"])["math_score"]
student_school_math

# %%
# Calculate the average math scores.
per_school_averages = school_data_complete_df.groupby(["school_name"]).mean()
per_school_averages

# %%
# Calculate the average test scores.
per_school_math = school_data_complete_df.groupby(["school_name"]).mean()["math_score"]

per_school_math

# %%
per_school_reading = school_data_complete_df.groupby(["school_name"]).mean()["reading_score"]
per_school_reading

# %%
# Calculate the passing scores by creating a filtered DataFrame.
per_school_passing_math = school_data_complete_df[(school_data_complete_df["math_score"] >= 70)]

per_school_passing_reading = school_data_complete_df[(school_data_complete_df["reading_score"] >= 70)]

# %%
# Calculate the number of students passing math and passing reading by school.
per_school_passing_math = per_school_passing_math.groupby(["school_name"]).count()["student_name"]

per_school_passing_reading = per_school_passing_reading.groupby(["school_name"]).count()["student_name"]

# %%
per_school_passing_math

# %%
 #Calculate the percentage of passing math and reading scores per school.
per_school_passing_math = per_school_passing_math / per_school_counts * 100

per_school_passing_reading = per_school_passing_reading / per_school_counts * 100

per_school_passing_reading

# %%
per_school_passing_math

# %%
per_school_passing_math

# %%
# Calculate the students who passed both math and reading.
per_passing_math_reading = school_data_complete_df[(school_data_complete_df["math_score"] >= 70) & (school_data_complete_df["reading_score"] >= 70)]

per_passing_math_reading.head()

# %%
# Calculate the number of students who passed both math and reading.
per_passing_math_reading = per_passing_math_reading.groupby(["school_name"]).count()["student_name"]
per_passing_math_reading

# %%
# Calculate the overall passing percentage.
per_overall_passing_percentage = per_passing_math_reading / per_school_counts * 100
per_overall_passing_percentage

# %%
per_school_summary_df = pd.DataFrame({
    "School Type": per_school_types,
             "Total Students": per_school_counts,
             "Total School Budget": per_school_budget,
             "Per Student Budget": per_school_capita,
             "Average Math Score": per_school_math,
           "Average Reading Score": per_school_reading,
           "% Passing Math": per_school_passing_math,
           "% Passing Reading": per_school_passing_reading,
           "% Overall Passing": per_overall_passing_percentage
})
per_school_summary_df

# %%
per_school_summary_df["Total School Budget"] = per_school_summary_df["Total School Budget"].map("${:,.2f}".format)

# %%
per_school_summary_df["Per Student Budget"] = per_school_summary_df["Per Student Budget"].map("${:,.2f}".format)

# Display the data frame
per_school_summary_df.head()

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ["School Type", "Total Students", "Total School Budget", "Per Student Budget", "Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing"]

# Assign district summary df the new column order.
per_school_summary_df = per_school_summary_df[new_column_order]

per_school_summary_df.head()

# %%
top_schools = per_school_summary_df.sort_values(["% Overall Passing"], ascending = False)
top_schools.head()

# %%
bottom_schools = per_school_summary_df.sort_values(["% Overall Passing"] )
bottom_schools.head()

# %%
# Create a grade level DataFrames.
ninth_graders = school_data_complete_df[(school_data_complete_df["grade"] == "9th")]

tenth_graders = school_data_complete_df[(school_data_complete_df["grade"] == "10th")]

eleventh_graders = school_data_complete_df[(school_data_complete_df["grade"] == "11th")]

twelfth_graders = school_data_complete_df[(school_data_complete_df["grade"] == "12th")]

# %%
ninth_graders.head()

# %%
ninth_grade_math_scores = ninth_graders.groupby(["school_name"]).mean()["math_score"]
tenth_grade_math_scores = tenth_graders.groupby(["school_name"]).mean()["math_score"]

eleventh_grade_math_scores = eleventh_graders.groupby(["school_name"]).mean()["math_score"]

twelfth_grade_math_scores = twelfth_graders.groupby(["school_name"]).mean()["math_score"]

eleventh_grade_math_scores

# %%
# Group each school Series by the school name for the average reading score.
ninth_grade_reading_scores = ninth_graders.groupby(["school_name"]).mean()["reading_score"]

tenth_grade_reading_scores = tenth_graders.groupby(["school_name"]).mean()["reading_score"]

eleventh_grade_reading_scores = eleventh_graders.groupby(["school_name"]).mean()["reading_score"]

twelfth_grade_reading_scores = twelfth_graders.groupby(["school_name"]).mean()["reading_score"]

twelfth_grade_reading_scores

# %%
math_scores_by_grade = pd.DataFrame ( {
                "9th": ninth_grade_math_scores,
               "10th": tenth_grade_math_scores,
               "11th": eleventh_grade_math_scores,
               "12th": twelfth_grade_math_scores 
                } )

math_scores_by_grade.head()

# %%
# Combine each Series for average reading scores by school into single DataFrame.
reading_scores_by_grade = pd.DataFrame({
              "9th": ninth_grade_reading_scores,
              "10th": tenth_grade_reading_scores,
              "11th": eleventh_grade_reading_scores,
              "12th": twelfth_grade_reading_scores})

reading_scores_by_grade.head()

# %%
  # Format each grade column.
  math_scores_by_grade["9th"] = math_scores_by_grade["9th"].map("{:.1f}".format)

  math_scores_by_grade["10th"] = math_scores_by_grade["10th"].map("{:.1f}".format)

  math_scores_by_grade["11th"] = math_scores_by_grade["11th"].map("{:.1f}".format)

  math_scores_by_grade["12th"] = math_scores_by_grade["12th"].map("{:.1f}".format)

  # Make sure the columns are in the correct order.
  math_scores_by_grade = math_scores_by_grade[
                 ["9th", "10th", "11th", "12th"]]

  # Remove the index name.
  math_scores_by_grade.index.name = None
  # Display the DataFrame.
  math_scores_by_grade.describe()

# %%
  # Format each grade column.
  reading_scores_by_grade["9th"] = reading_scores_by_grade["9th"].map("{:,.1f}".format)

  reading_scores_by_grade["10th"] = reading_scores_by_grade["10th"].map("{:,.1f}".format)

  reading_scores_by_grade["11th"] = reading_scores_by_grade["11th"].map("{:,.1f}".format)

  reading_scores_by_grade["12th"] = reading_scores_by_grade["12th"].map("{:,.1f}".format)

  # Make sure the columns are in the correct order.
  reading_scores_by_grade = reading_scores_by_grade[
                 ["9th", "10th", "11th", "12th"]]

  # Remove the index name.
  reading_scores_by_grade.index.name = None
  # Display the data frame.
  reading_scores_by_grade.head()

# %%
# Get the descriptive statistics for the per_school_capita.
per_school_capita.describe()

# %%
# Cut the per_school_capita into the spending ranges.
spending_bins = [0, 585, 615, 645, 675]
pd.cut(per_school_capita, spending_bins)

# %%
# Cut the per_school_capita into the spending ranges.
spending_bins = [585, 615, 645, 675]
pd.cut(per_school_capita, spending_bins)

# %%
# Cut the per_school_capita into the spending ranges.
spending_bins = [0, 585, 615, 645, 675]
per_school_capita.groupby(pd.cut(per_school_capita, spending_bins)).count()

# %%
# Establish the spending bins and group names.
spending_bins = [0, 585, 630, 645, 675]
group_names = ["<$584", "$585-629", "$630-644", "$645-675"]

# %%
# Categorize spending based on the bins.
per_school_summary_df["Spending Ranges (Per Student)"] = pd.cut(per_school_capita, spending_bins, labels=group_names)

per_school_summary_df

# %%
# Calculate averages for the desired columns.
spending_math_scores = per_school_summary_df.groupby(["Spending Ranges (Per Student)"]).mean()["Average Math Score"]

spending_reading_scores = per_school_summary_df.groupby(["Spending Ranges (Per Student)"]).mean()["Average Reading Score"]

spending_passing_math = per_school_summary_df.groupby(["Spending Ranges (Per Student)"]).mean()["% Passing Math"]

spending_passing_reading = per_school_summary_df.groupby(["Spending Ranges (Per Student)"]).mean()["% Passing Reading"]

overall_passing_spending = per_school_summary_df.groupby(["Spending Ranges (Per Student)"]).mean()["% Overall Passing"]
overall_passing_spending

# %%
# Assemble into DataFrame.
spending_summary_df = pd.DataFrame({ "Average Math Score":spending_math_scores,
  "Average Reading Score" :spending_reading_scores,  "% Passing Math":spending_passing_math, 
  "% Passing Reading":spending_passing_reading, "% Overall Passing":overall_passing_spending
                                    
})
spending_summary_df
# Out:
#                                Average Math Score  Average Reading Score  \
# Spending Ranges (Per Student)
# <$584                                   83.455399              83.933814
# $585-629                                81.899826              83.155286
# $630-644                                78.518855              81.624473
# $645-675                                76.997210              81.027843
#
#                                % Passing Math  % Passing Reading  \
# Spending Ranges (Per Student)
# <$584                               93.460096          96.610877
# $585-629                            87.133538          92.718205
# $630-644                            73.484209          84.391793
# $645-675                            66.164813          81.133951
#
#                                % Overall Passing
# Spending Ranges (Per Student)
# <$584                                  90.369459
# $585-629                               81.418596
# $630-644                               62.857656
# $645-675                               53.526855

# %%
spending_summary_df["Average Math Score"] = spending_summary_df["Average Math Score"].map("{:.1f}".format)

spending_summary_df["Average Reading Score"] = spending_summary_df["Average Reading Score"].map("{:.1f}".format)

spending_summary_df["% Passing Math"] = spending_summary_df["% Passing Math"].map("{:.0f}".format)

spending_summary_df["% Passing Reading"] = spending_summary_df["% Passing Reading"].map("{:.0f}".format)

spending_summary_df["% Overall Passing"] = spending_summary_df["% Overall Passing"].map("{:.0f}".format)

spending_summary_df
# Out:
#                               Average Math Score Average Reading Score  \
# Spending Ranges (Per Student)
# <$584                                       83.5                  83.9
# $585-629                                    81.9                  83.2
# $630-644                                    78.5                  81.6
# $645-675                                    77.0                  81.0
#
#                               % Passing Math % Passing Reading  \
# Spending Ranges (Per Student)
# <$584                                     93                97
# $585-629                                  87                93
# $630-644                                  73                84
# $645-675                                  66                81
#
#                               % Overall Passing
# Spending Ranges (Per Student)
# <$584                                        90
# $585-629                                     81
# $630-644                                     63
# $645-675                                     54
