# %%
 # import dependencies
import pandas as pd  # Create a data frame with given columns and value
hey_arnold = pd.DataFrame(
    {"Character_in_show": ["Arnold", "Gerald", "Helga", "Phoebe", "Harold", "Eugene"],
     "color_of_hair": ["blonde", "black", "blonde", "black", "unknown", "red"],
     "Height": ["average", "tallish", "tallish", "short", "tall", "short"],
     "Football_Shaped_Head": [True, False, False, False, False, False]
     })

hey_arnold
# Out:
#   Character_in_show color_of_hair   Height  Football_Shaped_Head
# 0            Arnold        blonde  average                  True
# 1            Gerald         black  tallish                 False
# 2             Helga        blonde  tallish                 False
# 3            Phoebe         black    short                 False
# 4            Harold       unknown     tall                 False
# 5            Eugene           red    short                 False

# %%
# Rename columns to clean up the look  
hey_arnold_renamed = hey_arnold.rename(columns={"Character_in_show" : "Character"}) 
hey_arnold_renamed
# Out:
#   Character color_of_hair   Height  Football_Shaped_Head
# 0    Arnold        blonde  average                  True
# 1    Gerald         black  tallish                 False
# 2     Helga        blonde  tallish                 False
# 3    Phoebe         black    short                 False
# 4    Harold       unknown     tall                 False
# 5    Eugene           red    short                 False

# %%
hey_arnold_reorder = hey_arnold_renamed["Character","color_of_hair", "height", "Football_Shaped_Head"]
hey_arnold_reorder
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Character', 'color_of_hair', 'height', 'Football_Shaped_Head')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
